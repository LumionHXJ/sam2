# %%
import os
import shutil
file_list = os.listdir('data/OBIMD_hd_test/facsimile')
for file in file_list:
    shutil.copy(os.path.join('data/hd_50_newest_init', file), os.path.join('data/OBIMD_hd_test/rubbing', file))
